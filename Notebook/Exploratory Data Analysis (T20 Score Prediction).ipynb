# %%
# Import the important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import pickle

# %%
# Load the dataset
df = pickle.load(open('data_level3.pkl','rb'))

# %%
# Call the dataframe
df
# Out:
#       batting_team  bowling_team         city  current_score  balls_left  \
# 4267         India  South Africa    Cape Town            152           9
# 2185   New Zealand     Australia     Auckland             93          57
# 24878     Pakistan     Sri Lanka      Colombo             90          42
# 18652      England   West Indies     Barbados            117          24
# 27755  Afghanistan     Sri Lanka      Kolkata             43          75
# ...            ...           ...          ...            ...         ...
# 8575     Australia  South Africa    Cape Town            155          18
# 16388    Australia       England  Southampton            244           2
# 10113      England     Australia  Southampton            117          30
# 6239     Australia         India    Melbourne            101          21
# 19668  West Indies   New Zealand   Wellington             86          43
#
#        wickets_left        crr  last_five  runs_x
# ...

# %%
# Countplot
for i in df.columns:
    plt.figure(figsize=(15,6))
    sns.countplot(x=df[i], data = df, palette = 'hls')
    plt.xticks(rotation = 90)
    plt.show()

# %%
# To get the insights about the distribution of each features
for i in df.columns:
    plt.figure(figsize=(15,6))
    sns.histplot(df[i], kde = True, palette = 'hls')
    plt.xticks(rotation = 90)
    plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_800\3239460346.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, palette = 'hls')
# C:\Users\patel\AppData\Local\Temp\ipykernel_800\3239460346.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, palette = 'hls')
# C:\Users\patel\AppData\Local\Temp\ipykernel_800\3239460346.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, palette = 'hls')
# C:\Users\patel\AppData\Local\Temp\ipykernel_800\3239460346.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, palette = 'hls')
# C:\Users\patel\AppData\Local\Temp\ipykernel_800\3239460346.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, palette = 'hls')
# ...

# %%
df_new = df[["batting_team","bowling_team","city"]]

# %%
for i in df_new:
    plt.figure(figsize=(30,20)) 
    plt.pie(df[i].value_counts(), labels=df[i].value_counts().index, autopct='%1.1f%%', textprops={ 'fontsize': 25,
                                                                                                           'color': 'black',
                                                                                                           'weight': 'bold',
                                                                                                           'family': 'serif' }) 
    hfont = {'fontname':'serif', 'weight': 'bold'}
    plt.title(i, size=20, **hfont) 
    plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = df['batting_team'], y = df['runs_x'], palette = 'hls')
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_800\3567283678.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x = df['batting_team'], y = df['runs_x'], palette = 'hls')
# <Axes: xlabel='batting_team', ylabel='runs_x'>

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x = df['city'], y = df['runs_x'], palette = 'hls')
plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_800\3063411911.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x = df['city'], y = df['runs_x'], palette = 'hls')

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = df['city'], y = df['crr'], palette = 'hls')
plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_800\101053234.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x = df['city'], y = df['crr'], palette = 'hls')

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = df['city'], y = df['crr'], palette = 'hls')
plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_800\2768759857.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x = df['city'], y = df['crr'], palette = 'hls')

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = df['city'], y = df['runs_x'], palette = 'hls')
plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_800\3331573824.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x = df['city'], y = df['runs_x'], palette = 'hls')

# %%
df.hist(bins=50,figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'current_score'}>,
#         <Axes: title={'center': 'balls_left'}>],
#        [<Axes: title={'center': 'wickets_left'}>,
#         <Axes: title={'center': 'crr'}>],
#        [<Axes: title={'center': 'last_five'}>,
#         <Axes: title={'center': 'runs_x'}>]], dtype=object)

# %%
cor_matrix = df.corr()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_800\1746568915.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_matrix = df.corr()

# %%
plt.style.use("default")
plt.figure(figsize=(10, 8))
# setting the parameter values
cmap = "tab20"
center = 0
# setting the parameter values
linewidths = 2
linecolor = "red"
# Plotting the heatmap
sns.heatmap(cor_matrix,cmap=cmap, center=center,linewidths=linewidths,linecolor=linecolor,annot=True)
plt.show()
